# %%
import pandas as pd

# %%
df = pd.read_csv('phoneprices.csv')

df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.values
# Out:
# array([[8.420e+02, 0.000e+00, 2.200e+00, ..., 0.000e+00, 1.000e+00,
#         1.000e+00],
#        [1.021e+03, 1.000e+00, 5.000e-01, ..., 1.000e+00, 0.000e+00,
#         2.000e+00],
#        [5.630e+02, 1.000e+00, 5.000e-01, ..., 1.000e+00, 0.000e+00,
#         2.000e+00],
#        ...,
#        [1.911e+03, 0.000e+00, 9.000e-01, ..., 1.000e+00, 0.000e+00,
#         3.000e+00],
#        [1.512e+03, 0.000e+00, 9.000e-01, ..., 1.000e+00, 1.000e+00,
#         0.000e+00],
#        [5.100e+02, 1.000e+00, 2.000e+00, ..., 1.000e+00, 1.000e+00,
#         3.000e+00]])

# %%
df_stats = df.describe(include='all')

df_stats
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df['battery_power'].hist(bins=30)
# Out:
# <AxesSubplot: >

# %%
df['battery_power'].plot.kde()
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# Length: 2000, dtype: int64

# %%
df.plot.scatter(x='battery_power', y='ram')
# Out:
# <AxesSubplot: xlabel='battery_power', ylabel='ram'>

# %%
df_subset = df[['battery_power', 'ram', 'clock_speed']]

pd.plotting.scatter_matrix(df_subset)
# Out:
# array([[<AxesSubplot: xlabel='battery_power', ylabel='battery_power'>,
#         <AxesSubplot: xlabel='ram', ylabel='battery_power'>,
#         <AxesSubplot: xlabel='clock_speed', ylabel='battery_power'>],
#        [<AxesSubplot: xlabel='battery_power', ylabel='ram'>,
#         <AxesSubplot: xlabel='ram', ylabel='ram'>,
#         <AxesSubplot: xlabel='clock_speed', ylabel='ram'>],
#        [<AxesSubplot: xlabel='battery_power', ylabel='clock_speed'>,
#         <AxesSubplot: xlabel='ram', ylabel='clock_speed'>,
#         <AxesSubplot: xlabel='clock_speed', ylabel='clock_speed'>]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt

df_0 = df[['ram', 'clock_speed']][df['price_range'] == 0]
df_1 = df[['ram', 'clock_speed']][df['price_range'] == 1]
df_2 = df[['ram', 'clock_speed']][df['price_range'] == 2]
df_3 = df[['ram', 'clock_speed']][df['price_range'] == 3]

plt.scatter(df_0['ram'], df_0['clock_speed'], c='red', label='low end')
plt.scatter(df_1['ram'], df_1['clock_speed'], c='blue', label='entry level')
plt.scatter(df_2['ram'], df_2['clock_speed'], c='green', label='high end')
plt.scatter(df_3['ram'], df_3['clock_speed'], c='yellow', label='luxury')

plt.xlabel('RAM')
plt.ylabel('Clock Speed')
plt.legend()
plt.grid()
plt.show()

# %%
df.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
import seaborn as sns

sns.heatmap(df.corr())
# Out:
# <AxesSubplot: >

# %%
x = df.iloc[:,:-1]

x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y = df['price_range']

y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
sns.heatmap(x.corr(), annot=True)
# Out:
# <AxesSubplot: >

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

k = 5

scores = []
average = 0.00

for i in range(k):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=4)
    
    # Perform evaluating our model
    model_knn = RandomForestClassifier()
    model_knn.fit(x_train, y_train)
    
    predictions = model_knn.predict(x_test)
    
    score = accuracy_score(y_test, predictions)
    print("Score: {}".format(score))
    
    average += score

average = average / k

print("Average Score: {}".format(average))
# Out:
# Score: 0.875
# Score: 0.8675
# Score: 0.89
# Score: 0.8725
# Score: 0.8975
# Average Score: 0.8805
